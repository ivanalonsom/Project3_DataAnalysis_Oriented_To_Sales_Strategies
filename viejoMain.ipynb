# %%
import requests

# Endpoint de la API de CheapShark
url_sales = "https://www.cheapshark.com/api/1.0/deals"

url_stores = "https://www.cheapshark.com/api/1.0/stores"

# Parámetros para la solicitud (puedes personalizarlos según la documentación de la API)
params = {
    #"storeID": 25,     # ID de la tienda (opcional)
    #"upperPrice": 100, # Precio máximo (opcional)
    "pageNumber": 0   # Número de página (opcional)
}

# Realizar la solicitud GET
response_sales = requests.get(url_sales, params=params)
response_stores = requests.get(url_stores)

# Verificar si la solicitud fue exitosa
if response_sales.status_code == 200:
    # Convertir la respuesta JSON a un diccionario de Python
    deals = response_sales.json()

if response_stores.status_code == 200:
    stores = response_stores.json()

# %%
deals[0].keys()
# Out:
# dict_keys(['internalName', 'title', 'metacriticLink', 'dealID', 'storeID', 'gameID', 'salePrice', 'normalPrice', 'isOnSale', 'savings', 'metacriticScore', 'steamRatingText', 'steamRatingPercent', 'steamRatingCount', 'steamAppID', 'releaseDate', 'lastChange', 'dealRating', 'thumb'])

# %%
for x in deals:
    print(x["title"])
    print(x["salePrice"])
    print(x["normalPrice"])
    print(x["savings"])
# Out:
# Football Manager 2024
# 0.00
# 59.99
# 100.000000
# Sniper Ghost Warrior Contracts
# 0.00
# 29.99
# 100.000000
# The Incredible Adventures of Van Helsing Anthology
# 5.63
# 74.99
# 92.492332
# Cycling Bundle 2021
# 7.83
# 69.58
# 88.746766
# Tennis World Tour Legends Edition
# 7.88
# 69.98
# 88.739640
# Assassin's Creed Odyssey - Deluxe Edition
# 11.19
# 79.99
# 86.010751
# Warhammer Age of Sigmar: Realms of Ruin Ultimate Edition
# 12.29
# 74.99
# 83.611148
# Assassins Creed Origins Gold Edition
# 13.88
# 99.99
# 86.118612
# Sid Meiers Civilization VI: Platinum Edition
# 8.89
# 79.99
# 88.886111
# Assassins Creed Odyssey Gold Edition
# 13.99
# 99.99
# 86.008601
# Assassins Creed Odyssey Ultimate Edition
# 16.69
# 119.99
# 86.090508
# Warhammer Age of Sigmar: Realms of Ruin Ultimate Edition
# 13.49
# 74.99
# 82.010935
# Warhammer Age of Sigmar: Realms of Ruin Ultimate Edition
# 13.50
# 74.99
# 81.997600
# Sid Meiers Civilization VI: Platinum Edition
# 10.44
# 79.99
# 86.948369
# BioShock Infinite
# 3.19
# 29.99
# 89.363121
# NHRA: Speed for All - Ultimate Edition
# 7.99
# 79.99
# 90.011251
# Chivalry - 4 Pack
# 12.00
# 74.99
# 83.997866
# Assassins Creed Valhalla Deluxe Edition
# 14.75
# 79.99
# 81.560195
# Nickelodeon All-Star Brawl 2
# 4.25
# 49.99
# 91.498300
# Warhammer Age of Sigmar: Realms of Ruin Ultimate Edition
# 12.60
# 74.99
# 83.197760
# Assassins Creed Valhalla - Ragnark Edition
# 17.99
# 99.99
# 82.008201
# Riders Republic 360 Edition
# 17.60
# 79.99
# 77.997250
# Assassins Creed Valhalla - Complete Edition
# 24.99
# 139.99
# 82.148725
# Maximum Entertainment Bundle
# 4.64
# 92.94
# 95.007532
# Deus Ex: Human Revolution - Director's Cut
# 2.52
# 19.99
# 87.393697
# Riders Republic - Complete Edition
# 22.00
# 99.99
# 77.997800
# DEATHLOOP - Deluxe Edition
# 15.99
# 79.99
# 80.010001
# Star Wars: Knights of the Old Republic
# 2.26
# 9.99
# 77.377377
# Robin Hood: The Legend of Sherwood
# 0.70
# 7.99
# 91.239049
# When Ski Lifts Go Wrong
# 1.31
# 14.99
# 91.260841
# Sid Meiers Civilization VI
# 4.49
# 59.99
# 92.515419
# Bury me, my Love
# 0.38
# 4.99
# 92.384770
# Hacknet
# 0.92
# 9.99
# 90.790791
# Return To Mysterious Island
# 0.70
# 7.99
# 91.239049
# Deus Ex: Human Revolution - Director's Cut
# 2.99
# 19.99
# 85.042521
# Ultra Street Fighter IV
# 3.10
# 29.99
# 89.663221
# Star Wars: Knights of the Old Republic
# 2.49
# 9.99
# 75.075075
# Cyber Avenger
# 0.71
# 17.99
# 96.053363
# Star Wars: Knights of the Old Republic
# 2.50
# 9.99
# 74.974975
# Thief: Deadly Shadows
# 0.83
# 8.99
# 90.767519
# SteamWorld Heist
# 1.35
# 14.99
# 90.993996
# When Ski Lifts Go Wrong
# 1.50
# 14.99
# 89.993329
# Thief II: The Metal Age
# 0.82
# 6.99
# 88.268956
# Return To Mysterious Island
# 0.79
# 7.99
# 90.112641
# Sid Meiers Civilization VI
# 5.99
# 59.99
# 90.015003
# Sid Meiers Civilization VI
# 5.22
# 59.99
# 91.298550
# Star Wars Jedi Knight: Dark Forces II
# 1.38
# 5.99
# 76.961603
# SteamWorld Dig 2
# 2.65
# 19.99
# 86.743372
# The Incredible Adventures of Van Helsing Final Cut
# 3.38
# 44.99
# 92.487219
# Splasher
# 1.32
# 14.99
# 91.194129
# The Incredible Adventures of Van Helsing II
# 1.13
# 14.99
# 92.461641
# Borderlands 3 Super Deluxe Edition (EPIC)
# 17.40
# 79.99
# 78.247281
# Borderlands 3 Super Deluxe Edition
# 17.40
# 79.99
# 78.247281
# Tiny Tinas Wonderlands: Chaotic Great Edition
# 17.40
# 79.99
# 78.247281
# Marvels Midnight Suns Digital Edition
# 17.40
# 79.99
# 78.247281
# Thief: Deadly Shadows
# 0.98
# 8.99
# 89.098999
# Star Wars Collection
# 24.99
# 99.99
# 75.007501
# Deathtrap
# 1.50
# 19.99
# 92.496248
# Disco Elysium - The Final Cut
# 10.00
# 39.99
# 74.993748
# Still Life
# 0.70
# 7.99
# 91.239049

# %%
dict_tiendas = {}

for x in stores:
    dict_tiendas[x["storeID"]] = x["storeName"]

dict_tiendas
# Out:
# {'1': 'Steam',
#  '2': 'GamersGate',
#  '3': 'GreenManGaming',
#  '4': 'Amazon',
#  '5': 'GameStop',
#  '6': 'Direct2Drive',
#  '7': 'GOG',
#  '8': 'Origin',
#  '9': 'Get Games',
#  '10': 'Shiny Loot',
#  '11': 'Humble Store',
#  '12': 'Desura',
#  '13': 'Uplay',
#  '14': 'IndieGameStand',
#  '15': 'Fanatical',
#  '16': 'Gamesrocket',
#  '17': 'Games Republic',
#  '18': 'SilaGames',
#  '19': 'Playfield',
#  '20': 'ImperialGames',
#  '21': 'WinGameStore',
#  '22': 'FunStockDigital',
#  '23': 'GameBillet',
#  '24': 'Voidu',
#  '25': 'Epic Games Store',
#  '26': 'Razer Game Store',
#  '27': 'Gamesplanet',
#  '28': 'Gamesload',
#  '29': '2Game',
#  '30': 'IndieGala',
#  '31': 'Blizzard Shop',
#  '32': 'AllYouPlay',
#  '33': 'DLGamer',
#  '34': 'Noctre',
#  '35': 'DreamGame'}

# %%
deals[0]
# Out:
# {'internalName': 'FOOTBALLMANAGER2024',
#  'title': 'Football Manager 2024',
#  'metacriticLink': '/game/football-manager-2024/',
#  'dealID': 'RdobOWYozyvPqR%2FGjn1f9Y2z032XOy2pmFT17rAJspA%3D',
#  'storeID': '25',
#  'gameID': '272713',
#  'salePrice': '0.00',
#  'normalPrice': '59.99',
#  'isOnSale': '1',
#  'savings': '100.000000',
#  'metacriticScore': '84',
#  'steamRatingText': 'Very Positive',
#  'steamRatingPercent': '90',
#  'steamRatingCount': '9579',
#  'steamAppID': '2252570',
#  'releaseDate': 1699228800,
#  'lastChange': 1725549775,
#  'dealRating': '10.0',
#  'thumb': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2252570/capsule_sm_120.jpg?t=1702984758'}

# %%
# dict_juegos = {}

# for x in deals:
#     dict_juegos[x["title"]] = [x["storeID"], x["savings"].split('.')[0], x["metacriticScore"]]

# dict_juegos

# %%
lista_tiendas = []
lista_nombres = []
lista_precio_original = []
lista_precio_descuento = []
lista_perc_descuento = []
lista_metacritic = []



for x in deals:
      lista_tiendas.append(dict_tiendas[x["storeID"]])
    
      lista_precio_original.append(x["normalPrice"])

      lista_precio_descuento.append(x["salePrice"])

      lista_nombres.append(x["title"])
    
      lista_perc_descuento.append(round( float(x["savings"]), 2) )

      lista_metacritic.append(float(x["metacriticScore"]))

# %%
import pandas as pd

lista_zip = list(zip(lista_nombres, lista_tiendas, lista_precio_original, lista_precio_descuento, lista_perc_descuento, lista_metacritic))

# %%
df_all = pd.DataFrame(lista_zip, columns=['título', 'tienda', 'precio_original', 'precio_descuento', 'porcentaje_descuento', 'metacritic'])

# %%
df_all
# Out:
#                                                título            tienda  \
# 0                               Football Manager 2024  Epic Games Store
# 1                      Sniper Ghost Warrior Contracts  Epic Games Store
# 2   The Incredible Adventures of Van Helsing Antho...        GamersGate
# 3                                 Cycling Bundle 2021        GamersGate
# 4                   Tennis World Tour Legends Edition        GamersGate
# 5           Assassin's Creed Odyssey - Deluxe Edition       Gamesplanet
# 6   Warhammer Age of Sigmar: Realms of Ruin Ultima...         IndieGala
# 7                Assassins Creed Origins Gold Edition       Gamesplanet
# 8        Sid Meiers Civilization VI: Platinum Edition      WinGameStore
# 9                Assassins Creed Odyssey Gold Edition       Gamesplanet
# 10           Assassins Creed Odyssey Ultimate Edition       Gamesplanet
# 11  Warhammer Age of Sigmar: Realms of Ruin Ultima...       Gamesplanet
# 12  Warhammer Age of Sigmar: Realms of Ruin Ultima...        GamersGate
# 13       Sid Meiers Civilization VI: Platinum Edition    GreenManGaming
# 14                                  BioShock Infinite      WinGameStore
# 15             NHRA: Speed for All - Ultimate Edition  Epic Games Store
# 16                                  Chivalry - 4 Pack    GreenManGaming
# 17            Assassins Creed Valhalla Deluxe Edition       Gamesplanet
# 18                       Nickelodeon All-Star Brawl 2        GamersGate
# 19  Warhammer Age of Sigmar: Realms of Ruin Ultima...    GreenManGaming
# 20         Assassins Creed Valhalla - Ragnark Edition       Gamesplanet
# 21                        Riders Republic 360 Edition    GreenManGaming
# 22        Assassins Creed Valhalla - Complete Edition       Gamesplanet
# 23                       Maximum Entertainment Bundle               GOG
# 24         Deus Ex: Human Revolution - Director's Cut    GreenManGaming
# 25                 Riders Republic - Complete Edition    GreenManGaming
# 26                         DEATHLOOP - Deluxe Edition      Humble Store
# 27             Star Wars: Knights of the Old Republic       Gamesplanet
# 28                 Robin Hood: The Legend of Sherwood        GamersGate
# 29                            When Ski Lifts Go Wrong        GamersGate
# 30                         Sid Meiers Civilization VI      WinGameStore
# 31                                   Bury me, my Love        GamersGate
# 32                                            Hacknet       Gamesplanet
# 33                        Return To Mysterious Island        GamersGate
# 34         Deus Ex: Human Revolution - Director's Cut      Humble Store
# 35                            Ultra Street Fighter IV       Gamesplanet
# 36             Star Wars: Knights of the Old Republic         IndieGala
# 37                                      Cyber Avenger      Humble Store
# 38             Star Wars: Knights of the Old Republic        GameBillet
# 39                              Thief: Deadly Shadows    GreenManGaming
# 40                                   SteamWorld Heist       Gamesplanet
# 41                            When Ski Lifts Go Wrong        GameBillet
# 42                            Thief II: The Metal Age    GreenManGaming
# 43                        Return To Mysterious Island         IndieGala
# 44                         Sid Meiers Civilization VI      Humble Store
# 45                         Sid Meiers Civilization VI    GreenManGaming
# 46              Star Wars Jedi Knight: Dark Forces II       Gamesplanet
# 47                                   SteamWorld Dig 2       Gamesplanet
# 48  The Incredible Adventures of Van Helsing Final...        GamersGate
# 49                                           Splasher       Gamesplanet
# 50        The Incredible Adventures of Van Helsing II        GamersGate
# 51          Borderlands 3 Super Deluxe Edition (EPIC)    GreenManGaming
# 52                 Borderlands 3 Super Deluxe Edition    GreenManGaming
# 53      Tiny Tinas Wonderlands: Chaotic Great Edition    GreenManGaming
# 54              Marvels Midnight Suns Digital Edition    GreenManGaming
# 55                              Thief: Deadly Shadows      Humble Store
# 56                               Star Wars Collection         IndieGala
# 57                                          Deathtrap        GamersGate
# 58                      Disco Elysium - The Final Cut    GreenManGaming
# 59                                         Still Life        GamersGate
#
#    precio_original precio_descuento  porcentaje_descuento  metacritic
# 0            59.99             0.00                100.00        84.0
# 1            29.99             0.00                100.00        71.0
# 2            74.99             5.63                 92.49         0.0
# 3            69.58             7.83                 88.75         0.0
# 4            69.98             7.88                 88.74         0.0
# 5            79.99            11.19                 86.01         0.0
# 6            74.99            12.29                 83.61         0.0
# 7            99.99            13.88                 86.12         0.0
# 8            79.99             8.89                 88.89         0.0
# 9            99.99            13.99                 86.01         0.0
# 10          119.99            16.69                 86.09         0.0
# 11           74.99            13.49                 82.01         0.0
# 12           74.99            13.50                 82.00         0.0
# 13           79.99            10.44                 86.95         0.0
# 14           29.99             3.19                 89.36        94.0
# 15           79.99             7.99                 90.01         0.0
# 16           74.99            12.00                 84.00         0.0
# 17           79.99            14.75                 81.56         0.0
# 18           49.99             4.25                 91.50        73.0
# 19           74.99            12.60                 83.20         0.0
# 20           99.99            17.99                 82.01         0.0
# 21           79.99            17.60                 78.00         0.0
# 22          139.99            24.99                 82.15         0.0
# 23           92.94             4.64                 95.01         0.0
# 24           19.99             2.52                 87.39        91.0
# 25           99.99            22.00                 78.00         0.0
# 26           79.99            15.99                 80.01         0.0
# 27            9.99             2.26                 77.38        93.0
# 28            7.99             0.70                 91.24        80.0
# 29           14.99             1.31                 91.26        80.0
# 30           59.99             4.49                 92.52        88.0
# 31            4.99             0.38                 92.38        80.0
# 32            9.99             0.92                 90.79        82.0
# 33            7.99             0.70                 91.24        79.0
# 34           19.99             2.99                 85.04        91.0
# 35           29.99             3.10                 89.66        82.0
# 36            9.99             2.49                 75.08        93.0
# 37           17.99             0.71                 96.05         0.0
# 38            9.99             2.50                 74.97        93.0
# 39            8.99             0.83                 90.77        85.0
# 40           14.99             1.35                 90.99        81.0
# 41           14.99             1.50                 89.99        80.0
# 42            6.99             0.82                 88.27        87.0
# 43            7.99             0.79                 90.11        79.0
# 44           59.99             5.99                 90.02        88.0
# 45           59.99             5.22                 91.30        88.0
# 46            5.99             1.38                 76.96        91.0
# 47           19.99             2.65                 86.74        85.0
# 48           44.99             3.38                 92.49        79.0
# 49           14.99             1.32                 91.19        79.0
# 50           14.99             1.13                 92.46        77.0
# 51           79.99            17.40                 78.25         0.0
# 52           79.99            17.40                 78.25         0.0
# 53           79.99            17.40                 78.25         0.0
# 54           79.99            17.40                 78.25         0.0
# 55            8.99             0.98                 89.10        85.0
# 56           99.99            24.99                 75.01         0.0
# 57           19.99             1.50                 92.50        77.0
# 58           39.99            10.00                 74.99        97.0
# 59            7.99             0.70                 91.24        75.0

# %%
from datetime import datetime

fecha_actual = datetime.now().strftime("%d-%m-%Y")

df_all.to_csv(f"data/registro_{fecha_actual}")

# %%
import matplotlib.pyplot as plt

df_graf_barras = df_all.groupby('tienda')['porcentaje_descuento'].mean().reset_index()
# Same as df_graf_barras = df_all.groupby('tienda').agg({'porcentaje_descuento' : 'mean'})

plt.figure(figsize=(15, 9))
plt.bar(df_graf_barras['tienda'], df_graf_barras['porcentaje_descuento'])

# Agregar etiquetas a cada barra
for i, valor in enumerate(df_graf_barras['porcentaje_descuento']):
    plt.text(i, valor + 1, f"{valor:.2f}", ha='center', va='bottom')

plt.title('Gráfico de barras de descuentos')
plt.xlabel('Tienda')
plt.ylabel('Descuento promedio')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo (reemplaza esto con tus datos)

# Calcular los valores máximos y mínimos por tienda
df_max = df_all.groupby('tienda')['porcentaje_descuento'].max().reset_index()
df_min = df_all.groupby('tienda')['porcentaje_descuento'].min().reset_index()

# Crear un DataFrame combinado
df_combined = df_max.merge(df_min, on='tienda', suffixes=('_max', '_min'))

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(15, 9))

# Crear posiciones para las barras
bar_width = 0.4
indices = np.arange(len(df_combined))

# Graficar las barras
ax.bar(indices - bar_width/2, df_combined['porcentaje_descuento_max'], width=bar_width, label='Max Descuento')
ax.bar(indices + bar_width/2, df_combined['porcentaje_descuento_min'], width=bar_width, label='Min Descuento')

# Agregar etiquetas a las barras
for i, (max_val, min_val) in enumerate(zip(df_combined['porcentaje_descuento_max'], df_combined['porcentaje_descuento_min'])):
    ax.text(i - bar_width/2, max_val + 1, f"{max_val:.2f}", ha='center', va='bottom')
    ax.text(i + bar_width/2, min_val + 1, f"{min_val:.2f}", ha='center', va='bottom')

# Configurar etiquetas y título
ax.set_title('Porcentaje de descuentos máximos y mínimos')
ax.set_xlabel('Tienda')
ax.set_ylabel('% Descuento')
ax.set_xticks(indices)
ax.set_xticklabels(df_combined['tienda'])
ax.legend()

plt.show()

# %%
df_plat_punt = df_all[df_all["metacritic"] > 0][["tienda", "porcentaje_descuento", "metacritic"]]

df_plat_punt.sort_values(by="metacritic", ascending=True, inplace=True)

df_plat_punt
# Out:
#               tienda  porcentaje_descuento  metacritic
# 1   Epic Games Store                100.00        71.0
# 18        GamersGate                 91.50        73.0
# 59        GamersGate                 91.24        75.0
# 57        GamersGate                 92.50        77.0
# 50        GamersGate                 92.46        77.0
# 49       Gamesplanet                 91.19        79.0
# 48        GamersGate                 92.49        79.0
# 33        GamersGate                 91.24        79.0
# 43         IndieGala                 90.11        79.0
# 28        GamersGate                 91.24        80.0
# 29        GamersGate                 91.26        80.0
# 31        GamersGate                 92.38        80.0
# 41        GameBillet                 89.99        80.0
# 40       Gamesplanet                 90.99        81.0
# 32       Gamesplanet                 90.79        82.0
# 35       Gamesplanet                 89.66        82.0
# 0   Epic Games Store                100.00        84.0
# 47       Gamesplanet                 86.74        85.0
# 55      Humble Store                 89.10        85.0
# 39    GreenManGaming                 90.77        85.0
# 42    GreenManGaming                 88.27        87.0
# 44      Humble Store                 90.02        88.0
# 45    GreenManGaming                 91.30        88.0
# 30      WinGameStore                 92.52        88.0
# 34      Humble Store                 85.04        91.0
# 46       Gamesplanet                 76.96        91.0
# 24    GreenManGaming                 87.39        91.0
# 36         IndieGala                 75.08        93.0
# 27       Gamesplanet                 77.38        93.0
# 38        GameBillet                 74.97        93.0
# 14      WinGameStore                 89.36        94.0
# 58    GreenManGaming                 74.99        97.0

# %%
# Creamos un gráfico de puntos con eje X puntuacion y eje Y descuento
plt.figure(figsize=(15, 9))
for tienda in df_plat_punt['tienda'].unique():
    df_tienda = df_plat_punt[df_plat_punt['tienda'] == tienda]
    plt.plot(df_tienda['metacritic'], df_tienda['porcentaje_descuento'], label=tienda, marker='o')

# Agregamos título y etiquetas a los ejes
plt.title('Descuento vs puntuacion')
plt.xlabel('Puntuacion')
plt.ylabel('Descuento')

# Agregamos leyenda
plt.legend()

# Mostramos el gráfico
plt.show()
